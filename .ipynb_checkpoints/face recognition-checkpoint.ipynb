# %%
# !pip install matplotlib
# !pip install numpy
# !pip install deepface
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\envs\deepface\lib\site-packages (3.5.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: typing-extensions in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from kiwisolver>=1.0.1->matplotlib) (4.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\deepface\lib\site-packages (1.21.6)
# Requirement already satisfied: deepface in c:\users\user\anaconda3\envs\deepface\lib\site-packages (0.0.79)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from deepface) (1.21.6)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from deepface) (2.11.0)
# Requirement already satisfied: fire>=0.4.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from deepface) (0.5.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from deepface) (21.2.0)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from deepface) (4.7.1)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from deepface) (4.8.0.74)
# Requirement already satisfied: keras>=2.2.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from deepface) (2.11.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from deepface) (9.5.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from deepface) (4.65.0)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from deepface) (2.2.5)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from deepface) (0.0.13)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from deepface) (1.3.5)
# Requirement already satisfied: six in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from fire>=0.4.0->deepface) (2.3.0)
# Requirement already satisfied: click>=8.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.6)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from Flask>=1.1.2->deepface) (6.7.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.3)
# Requirement already satisfied: requests[socks] in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from gdown>=3.10.1->deepface) (2.31.0)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from gdown>=3.10.1->deepface) (3.12.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from gunicorn>=20.1.0->deepface) (23.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.11.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (4.7.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (2.11.2)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (2.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (3.19.6)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (3.8.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (16.0.6)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (23.5.26)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (65.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (1.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (1.56.2)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from importlib-metadata>=3.6.0->Flask>=1.1.2->deepface) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.16)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2022.12.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (2.22.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (3.4.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\anaconda3\envs\deepface\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=1.9.0->deepface) (3.2.2)

# %%
import matplotlib.pyplot as plt
import numpy as np
from deepface import DeepFace
from deepface.commons import functions

# ----------------------------------------------
# build face recognition model

#model_name = "VGG-Face"
model_name = "Facenet"

model = DeepFace.build_model(model_name=model_name)

target_size = functions.find_target_size(model_name)

print(f"target_size: {target_size}")

# ----------------------------------------------
# load images and find embeddings

img1 = DeepFace.extract_faces(img_path="iu02.jpg", target_size=target_size)[0]["face"]
img1 = np.expand_dims(img1, axis=0)  # to (1, 224, 224, 3)
img1_representation = model.predict(img1)[0, :]

img2 = DeepFace.extract_faces(img_path="won01.jpg", target_size=target_size)[0]["face"]
img2 = np.expand_dims(img2, axis=0)
img2_representation = model.predict(img2)[0, :]

# ----------------------------------------------
# distance between two images

distance_vector = np.square(img1_representation - img2_representation)
print(distance_vector)

distance = np.sqrt(distance_vector.sum())
print("Euclidean distance: ", distance)

# ----------------------------------------------
# expand vectors to be shown better in graph

img1_graph = []
img2_graph = []
distance_graph = []

for i in range(0, 200):
    img1_graph.append(img1_representation)
    img2_graph.append(img2_representation)
    distance_graph.append(distance_vector)

img1_graph = np.array(img1_graph)
img2_graph = np.array(img2_graph)
distance_graph = np.array(distance_graph)

# ----------------------------------------------
# plotting

fig = plt.figure()

ax1 = fig.add_subplot(3, 2, 1)
plt.imshow(img1[0])
